# %% [raw]
# ---
# title: Nested Conditionals Homework
# comments: true
# codemirror: true
# layout: post
# permalink: /conditionalshw
# author: Rashi
# ---

# %%
const factorsof50 = [1, 2, 5, 10, 25, 50];

for (let num = 1; num <=50; num ++) {
    for (factor of factorsof50) {
        if (num % factor === 0) {
            console.log(factor);
            console.log(num + "is divisble by " + factor);
        }
    }
}
